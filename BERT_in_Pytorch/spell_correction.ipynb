# %%
import pandas as pd

from data_preparation import _load_dataset, _prepare_data

data_path = "../data/train.csv"

df = _load_dataset(data_path)
df = _prepare_data(df)

# %%
import pandas as pd
from model_preparation import set_seed
from data_preparation import _load_dataset, _prepare_data
from preprocessor import Preprocessor


data_path = "../data/train.csv"
model_name = 'microsoft/deberta-base'
batch_size = 16
create_validation_set = False
SEED = 42

set_seed(SEED)



def custom_clean_text(text: str) -> str:

    pipeline = ['hyperlinks', 'mentions', 'hashtags', 'retweet', 'repetitions', 'emojis', 'smileys', 'spaces']

    preprocessor = Preprocessor(pipeline)

    return preprocessor(text)


df = _load_dataset(data_path)

df = df.iloc[:100]

final_df = df["tweet"].copy()

df = _prepare_data(df, custom_clean_text)

df = pd.concat([final_df, df[["text","label"]]], axis = 1)

pd.set_option('display.max_colwidth', None)
# df.head(10)

# %%
from tqdm.auto import tqdm
import pkg_resources
from symspellpy import SymSpell

def correct_spell(df: pd.DataFrame, attribute='text'):
    sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
    dictionary_path = pkg_resources.resource_filename(
        "symspellpy", "frequency_dictionary_en_82_765.txt")
    bigram_path = pkg_resources.resource_filename(
        "symspellpy", "frequency_bigramdictionary_en_243_342.txt")
    # term_index is the column of the term and count_index is the
    # column of the term frequency
    sym_spell.load_dictionary(dictionary_path, term_index=0, count_index=1)
    sym_spell.load_bigram_dictionary(bigram_path, term_index=0, count_index=2)

    def check_spell(input_term):
        # lookup suggestions for multi-word input strings (supports compound
        # splitting & merging)
        # max edit distance per lookup (per single word, not per whole input string)
        suggestions = sym_spell.lookup_compound(input_term, max_edit_distance=2)
        # display suggestion term, edit distance, and term frequency
        progress_bar.update(1)
        return suggestions[0]._term

    progress_bar = tqdm(range(len(df[attribute])))
    df[attribute+"_spell"] = df[attribute].map(check_spell)

    return df

df = correct_spell(df = df, attribute = 'text')
df.head(20)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 252.48it/s]
#                                                                                                                                                  tweet  ...                                                                                                                        text_spell
# 0                                                                                                                                Puff puff pass ya hoe  ...                                                                                                              puff puff pass a hoe
# 1                                                                                                                              @jthizzle when was this  ...                                                                                                             mention when was this
# 2                                                                                                                TGIM (Thank God Its Monday) baby! 😀😀😀  ...                                                                                               tim thank god its monday baby emo i
# 3                                                                                                               Peace Love Shea http://t.co/SVG2yzx8L0  ...                                                                                                              peace love shea urls
# 4                                                                                                                        Same. https://t.co/GmP7Kz35yK  ...                                                                                                                         same urls
# 5                                                    "OTAKU: Loving someone who doesn't exist.\nKPOP fans: Loving someone who doesn't know you exist."  ...                                          take loving someone who doesn't exist pop fans loving someone who doesn't know you exist
# 6                                                                                                                      @ThatsMy_SON lol shutup but hmj  ...                                                                                                       mention low shut up but hmm
# 7                                               RT @brightongigs: TODAY: KYLMA SOTA (Fin) / HATE FUCK / FEROXITY in Cowley Club http://t.co/ZfuF57jVWW  ...                                                      re tweet mention today karma soma fin hate fuck ferocity in cowley club urls
# 8                                                                                    RT @Ashton5SOS: I like this photo of us :) http://t.co/vF9nWS9NAx  ...                                                                              re tweet mention i like this photo of us smiley urls
# 9                                                                                                                               Can't find shit on TV.  ...                                                                                                             can't find shit on to
# 10                                                                                   RT @TheDesBible: I dont want to go in today , i want to sleeppp:(  ...                                                                re tweet mention i done want to go in today i want to sleep smiley
# 11                                                                                                                               that's human nature..  ...                                                                                                               that's human nature
# 12       RT @maranathatweets: Psalms 70:5. \n“But I am poor and needy: make haste unto me, O God: thou art my help and my deliverer; O LORD, make no …  ...  re tweet mention psalms of a but i am poor and needy make haste unto me of god thou art my help and my deliverer of lord make no
# 13                                           And with that being said GOODNIGHT #whysoserious #thot #socalness  #socalthickness http://t.co/1RkpZ8uWAd  ...                                              and with that being said goodnight whys serious that local ness local thickness urls
# 14  “But you’ve slipped under my skin, invaded my blood and seized my heart.”\n\n🌸✨🍂\n\nI love you, \n\nMind following me?✨\n@Real_Liam_Payne \n\nx295  ...      but you've slipped under my skin invaded my blood and seized my heart emo i emo i i love you mind following me mention of of
# 15                                                                                       RT @TheSexualGifs: relationship status http://t.co/Yo0WypPVyJ  ...                                                                                         re tweet mention relationship status urls
# 16                                                                                  RT @Khunnie0624: CRAZY rumors hahaha that's just CRAZY #GOCRAZY!!!  ...                                                                 re tweet mention crazy rumours hah aha that's just crazy go crazy
# 17                                                                                                      You're able* \nHeavy tweets ruined by typos. 😒  ...                                                                                    you're able heavy sweets ruined by typos emo i
# 18                                                                                                 I love you will you marry me *DARE AGAIN* @RP_SeanP  ...                                                                                   i love you will you marry me dare again mention
# 19                                                             yes….breaking bad….yes. breaking stuff is bad. I'm not in fucking kindergarden.  thanks  ...                                                 yes breaking bad yes breaking stuff is bad i'm not in fucking kindergarten thanks
#
# [20 rows x 4 columns]
#  52%|█████▏    | 15375/29543 [01:12<00:52, 271.02it/s]

# %% [markdown]
# ### Stopwords with nltk (but we can use spacy) + punctiation (this is not needed I think)

# %%
import nltk
nltk.download('stopwords', download_dir='./')
# Out:
# [nltk_data] Downloading package stopwords to ./...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
import nltk
import string

nltk.data.path.append("./")
stopwords = stopwords.words('english')

def clean_puntuation_stopwords(text):
  text = ''.join([word for word in text if word not in string.punctuation])
  text = text.lower()
  text = ' '.join([word for word in text.split() if word not in stopwords])
  return text

df['text'] = df['text'].apply(clean_puntuation_stopwords)
df.head(20)
# Out:
#                                                  text label  \
# 0                               puff puff pass ya hoe     1
# 1                                                         0
# 2                      tgim thank god monday baby 😀😀😀     1
# 3                                     peace love shea     0
# 4                                                         0
# 5   otaku loving someone doesnt exist kpop fans lo...     1
# 6                                      lol shutup hmj     1
# 7   rt today kylma sota fin hate fuck feroxity cow...     1
# 8                                    rt like photo us     1
# 9                                   cant find shit tv     1
# 10                 rt dont want go today want sleeppp     1
# 11                                 thats human nature     0
# 12  rt psalms 705 “but poor needy make haste unto ...     1
# 13                                     said goodnight     0
# 14  “but you’ve slipped skin invaded blood seized ...     0
# 15                             rt relationship status     0
# 16                 rt crazy rumors hahaha thats crazy     1
# 17             youre able heavy tweets ruined typos 😒     1
# 18                                    love marry dare     0
# 19  yes…breaking bad…yes breaking stuff bad im fuc...     1
#
#                                            text_spell
# 0                                puff puff pass a hoe
# 1                                       when was this
# 2                       tim thank god its monday baby
# 3                                     peace love shea
# 4                                                same
# 5   take loving someone who doesn't exist pop fans...
# 6                                 low shut up but hmm
# 7   it today karma soma fin hate fuck ferocity in ...
# 8                          it i like this photo of us
# 9                               can't find shit on to
# 10    it i done want to go in today i want to sleep a
# 11                                that's human nature
# 12  it psalms of a but i am poor and needy make ha...
# 13                 and with that being said goodnight
# 14  but you've slipped under my skin invaded my bl...
# 15                             it relationship status
# 16         it crazy rumours hah aha that's just crazy
# 17           you're able heavy sweets ruined by typos
# 18            i love you will you marry me dare again
# 19  yes breaking bad yes breaking stuff is bad i'm...
