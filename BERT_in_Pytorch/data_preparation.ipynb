# %%
import pandas as pd
from model_preparation import set_seed
from data_preparation import _load_dataset, _prepare_data


data_path = "../data/train.csv"
model_name = 'microsoft/deberta-base'
batch_size = 16
create_validation_set = False
SEED = 42

set_seed(SEED)


df = _load_dataset(data_path)

df = df.iloc[:100]

final_df = df["tweet"].copy()

pipeline = ['hyperlinks', 'mentions', 'hashtags', 'retweet', 'repetitions', 'emojis', 'smileys', 'spaces']
df = _prepare_data(df, pipeline)

df = pd.concat([final_df, df[["text","label"]]], axis = 1)

pd.set_option('display.max_colwidth', None)
df.head(30)
# Out:
#                                                                                                                                                  tweet  \
# 0                                                                                                                                Puff puff pass ya hoe
# 1                                                                                                                              @jthizzle when was this
# 2                                                                                                                TGIM (Thank God Its Monday) baby! 😀😀😀
# 3                                                                                                               Peace Love Shea http://t.co/SVG2yzx8L0
# 4                                                                                                                        Same. https://t.co/GmP7Kz35yK
# 5                                                    "OTAKU: Loving someone who doesn't exist.\nKPOP fans: Loving someone who doesn't know you exist."
# 6                                                                                                                      @ThatsMy_SON lol shutup but hmj
# 7                                               RT @brightongigs: TODAY: KYLMA SOTA (Fin) / HATE FUCK / FEROXITY in Cowley Club http://t.co/ZfuF57jVWW
# 8                                                                                    RT @Ashton5SOS: I like this photo of us :) http://t.co/vF9nWS9NAx
# 9                                                                                                                               Can't find shit on TV.
# 10                                                                                   RT @TheDesBible: I dont want to go in today , i want to sleeppp:(
# 11                                                                                                                               that's human nature..
# 12       RT @maranathatweets: Psalms 70:5. \n“But I am poor and needy: make haste unto me, O God: thou art my help and my deliverer; O LORD, make no …
# 13                                           And with that being said GOODNIGHT #whysoserious #thot #socalness  #socalthickness http://t.co/1RkpZ8uWAd
# 14  “But you’ve slipped under my skin, invaded my blood and seized my heart.”\n\n🌸✨🍂\n\nI love you, \n\nMind following me?✨\n@Real_Liam_Payne \n\nx295
# 15                                                                                       RT @TheSexualGifs: relationship status http://t.co/Yo0WypPVyJ
# 16                                                                                  RT @Khunnie0624: CRAZY rumors hahaha that's just CRAZY #GOCRAZY!!!
# 17                                                                                                      You're able* \nHeavy tweets ruined by typos. 😒
# 18                                                                                                 I love you will you marry me *DARE AGAIN* @RP_SeanP
# 19                                                             yes….breaking bad….yes. breaking stuff is bad. I'm not in fucking kindergarden.  thanks
# 20                                                                     READ THIS #BOOK #2: Spoiling (Modern Plays) http://t.co/lCpdMQtbzE #Kindle #598
# 21                                                                                                                  ;) ASS: C R http://t.co/93s32FHY6s
# 22                                                                                                    i hate when people make assumptions about things
# 23                                                                 @leejieun1123__ hihi it's good i met new friend. :) take note, chanyeol biased too.
# 24            Former IGP Urges Northern Leaders To Save Nigeria From Insurgency: A former Inspector-General of Poli... http://t.co/cOGWhoN6De #Nigeria
# 25                                                               Study blowing engine mail-order selling task toward specialty esteem maturing: Uhkefe
# 26                                                     BoA and Her Father Charged with Illegal Development on “Green Belt” Land http://t.co/WFu2ODSo2r
# 27                                @StuTasmantuna big difference between having belongings checked at a voluntary event and indiscriminate spying. #MoT
# 28        RT @alaskanoutfit: Sometimes I shoot pictures of things out of the water. #Bears #Natgeowild @sam10k @jeffrey_ventre  Website 70% up http:/…
# 29                                                      I've collected 16,487 gold coins! http://t.co/nvwOe6eAKC #android, #androidgames, #gameinsight
#
#                                                                                                                                         text  \
# 0                                                                                                                      Puff puff pass ya hoe
# 1                                                                                                                      mention when was this
# 2                                                                                                   TGIM (Thank God Its Monday) baby! emoji
# 3                                                                                                                       Peace Love Shea url
# 4                                                                                                                                 Same. url
# 5                                           "OTAKU: Loving someone who doesn't exist. KPOP fans: Loving someone who doesn't know you exist."
# 6                                                                                                                 mention lol shutup but hmj
# 7                                                       retweet mention : TODAY: KYLMA SOTA (Fin) / HATE FUCK / FEROXITY in Cowley Club url
# 8                                                                                      retweet mention : I like this photo of us smiley url
# 9                                                                                                                     Can't find shit on TV.
# 10                                                                   retweet mention : I dont want to go in today , i want to sleepp smiley
# 11                                                                                                                     that's human nature..
# 12  retweet mention : Psalms 70:5. “But I am poor and needy: make haste unto me, O God: thou art my help and my deliverer; O LORD, make no …
# 13                                                        And with that being said GOODNIGHT whysoserious thot socalness socalthickness url
# 14      “But you’ve slipped under my skin, invaded my blood and seized my heart.” emoji ✨ emoji I love you, Mind following me?✨ mention x295
# 15                                                                                                retweet mention : relationship status url
# 16                                                                        retweet mention : CRAZY rumors hahaha that's just CRAZY GOCRAZY!!
# 17                                                                                         You're able* Heavy tweets ruined by typos. emoji
# 18                                                                                        I love you will you marry me *DARE AGAIN* mention
# 19                                                    yes….breaking bad….yes. breaking stuff is bad. I'm not in fucking kindergarden. thanks
# 20                                                                                 READ THIS BOOK 2: Spoiling (Modern Plays) url Kindle 598
# 21                                                                                                                      smiley ASS: C R url
# 22                                                                                          i hate when people make assumptions about things
# 23                                                           mention hihi it's good i met new friend. smiley take note, chanyeol biased too.
# 24                      Former IGP Urges Northern Leaders To Save Nigeria From Insurgency: A former Inspector-General of Poli.. url Nigeria
# 25                                                     Study blowing engine mail-order selling task toward specialty esteem maturing: Uhkefe
# 26                                                             BoA and Her Father Charged with Illegal Development on “Green Belt” Land url
# 27                             mention big difference between having belongings checked at a voluntary event and indiscriminate spying. MoT
# 28             retweet mention : Sometimes I shoot pictures of things out of the water. Bears Natgeowild mention mention Website 70% up url
# 29                                                                 I've collected 16,487 gold coins! url android, androidgames, gameinsight
#
#    label
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
# 5      1
# 6      1
# 7      1
# 8      1
# 9      1
# 10     1
# 11     0
# 12     1
# 13     0
# 14     0
# 15     0
# 16     1
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     1
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1

# %% [markdown]
# # Check spell on a DataFrame

# %%
from tqdm.auto import tqdm
import pkg_resources
from symspellpy import SymSpell

def correct_spell(df: pd.DataFrame, attribute='text'):
    sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
    dictionary_path = pkg_resources.resource_filename(
        "symspellpy", "frequency_dictionary_en_82_765.txt")
    bigram_path = pkg_resources.resource_filename(
        "symspellpy", "frequency_bigramdictionary_en_243_342.txt")
    # term_index is the column of the term and count_index is the
    # column of the term frequency
    sym_spell.load_dictionary(dictionary_path, term_index=0, count_index=1)
    sym_spell.load_bigram_dictionary(bigram_path, term_index=0, count_index=2)

    def check_spell(input_term):
        # lookup suggestions for multi-word input strings (supports compound
        # splitting & merging)
        # max edit distance per lookup (per single word, not per whole input string)
        suggestions = sym_spell.lookup_compound(input_term, max_edit_distance=2)
        # display suggestion term, edit distance, and term frequency
        progress_bar.update(1)
        return suggestions[0]._term

    progress_bar = tqdm(range(len(df[attribute])))
    df[attribute+"_spell"] = df[attribute].map(check_spell)

    return df

df = correct_spell(df = df, attribute = 'text')
df.head(20)

# %% [markdown]
# # Stopwords

# %% [markdown]
# ### Stopwords with nltk (but we can use spacy) + punctiation (this is not needed I think)

# %%
import nltk
nltk.download('stopwords', download_dir='./')

# %%
from nltk.corpus import stopwords
import nltk
import string

nltk.data.path.append("./")
stopwords = stopwords.words('english')

def clean_puntuation_stopwords(text):
  text = ''.join([word for word in text if word not in string.punctuation])
  text = text.lower()
  text = ' '.join([word for word in text.split() if word not in stopwords])
  return text

df['text'] = df['text'].apply(clean_puntuation_stopwords)
df.head(20)
