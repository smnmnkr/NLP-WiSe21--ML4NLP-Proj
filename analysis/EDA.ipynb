# %%
import pandas as pd

# Loading the data
train_raw = pd.read_csv('../data/train.csv', sep=',')
test_raw = pd.read_csv('../data/eval.csv', sep=',')

train_raw.head(5)
# Out:
#                    id                       time  \
# 0  511396190119022592  2014-09-15 06:08:47+00:00
# 1  511396219487133696  2014-09-15 06:08:54+00:00
# 2  511396894745309184  2014-09-15 06:11:35+00:00
# 3  511397226120097792  2014-09-15 06:12:54+00:00
# 4  511397255450853377  2014-09-15 06:13:01+00:00
#
#                                     tweet          smth lang         sent
# 0                   Puff puff pass ya hoe  4.551812e+08   en  Non_neutral
# 1                 @jthizzle when was this  2.265380e+09   en      Neutral
# 2   TGIM (Thank God Its Monday) baby! 😀😀😀  5.013839e+07   en  Non_neutral
# 3  Peace Love Shea http://t.co/SVG2yzx8L0  4.733844e+08   en      Neutral
# 4           Same. https://t.co/GmP7Kz35yK  2.279286e+08   en      Neutral

# %%
train_raw[train_raw["lang"]!="en"].head(40)
# Out:
#                        id                       time  \
# 200    511439668249108480  2014-09-15 09:01:33+00:00
# 823    511530265232302080  2014-09-15 15:01:33+00:00
# 828    511530869199491072  2014-09-15 15:03:57+00:00
# 879    511535889777176576  2014-09-15 15:23:54+00:00
# 932    511541057168101377  2014-09-15 15:44:26+00:00
# 1107   511559965086330880  2014-09-15 16:59:34+00:00
# 1934   511637614261469184  2014-09-15 22:08:07+00:00
# 2647   511699111121522688  2014-09-16 02:12:29+00:00
# 3038   511728722903171073  2014-09-16 04:10:09+00:00
# 3719   511849263018815488  2014-09-16 12:09:08+00:00
# 3954   511875838141149184  2014-09-16 13:54:44+00:00
# 4253   511907719025295361  2014-09-16 16:01:25+00:00
# 5342   512011502891843584  2014-09-16 22:53:49+00:00
# 5510   512027344773840897  2014-09-16 23:56:46+00:00
# 5544   512031039972450305  2014-09-17 00:11:27+00:00
# 6261   512104738091847680  2014-09-17 05:04:18+00:00
# 6676   512190507402153984  2014-09-17 10:45:07+00:00
# 7396   512275307861000192  2014-09-17 16:22:05+00:00
# 7832   512319536759312384  2014-09-17 19:17:50+00:00
# 8574   512393465565806593  2014-09-18 00:11:36+00:00
# 9301   512462260548034560  2014-09-18 04:44:58+00:00
# 9505   512495684964999168  2014-09-18 06:57:47+00:00
# 9839   512561455854415872  2014-09-18 11:19:08+00:00
# 10242  512607417017040896  2014-09-18 14:21:46+00:00
# 10599  512642200392318978  2014-09-18 16:39:59+00:00
# 10886  512671157846155265  2014-09-18 18:35:03+00:00
# 11019  512683363283374080  2014-09-18 19:23:33+00:00
# 11676  512747162833154048  2014-09-18 23:37:04+00:00
# 11951  512773314331176961  2014-09-19 01:20:59+00:00
# 12210  512791832200101888  2014-09-19 02:34:34+00:00
# 12859  512874548044505088  2014-09-19 08:03:15+00:00
# 13161  512931628339843072  2014-09-19 11:50:04+00:00
# 13485  512967254770974720  2014-09-19 14:11:38+00:00
# 13700  512986397565657088  2014-09-19 15:27:42+00:00
# 14282  513044580963729409  2014-09-19 19:18:54+00:00
# 14374  513053066036117505  2014-09-19 19:52:37+00:00
# 14402  513055691636871168  2014-09-19 20:03:03+00:00
# 15096  513139468673773568  2014-09-20 01:35:57+00:00
# 15105  513140018152755202  2014-09-20 01:38:08+00:00
# 15624  513209580659040256  2014-09-20 06:14:33+00:00
#
#                                                    tweet          smth lang  \
# 200         @alexxclarrke runnin' runnin'... runnin' run  5.826182e+08   fi
# 823               RT @I_am_lyric_1: @xolarrisa_ GM 👑😘☀️🌞  2.572815e+09  und
# 828    Lmfaooooooo RT @BrothaScoob: @KiraTheGOD_ @imj...  5.254262e+07   ht
# 879    Фотосет: sweetnitina: #LukeEvans at ‘Dracula U...  1.575098e+09   cs
# 932                        @netlagarto A-N-I-M-A-L &lt;3  9.030573e+08   es
# 1107                               @CristerCz hi crister  2.751557e+09   ca
# 1934                                 @sk8ingtiffers I do  9.870787e+08  und
# 2647                                  @jackgilinsky I am  1.653728e+09  und
# 3038                   @RajaFresh_ @_ahmedelhussein I am  1.109928e+09  und
# 3719   09/16 08:08 / Status (ESTAT) / DIST1 / -NO- / ...  3.702824e+08   ca
# 3954                                Denny's &gt;&gt;&gt;  9.374609e+08   hu
# 4253   16h Bastia centre: Temp. 23.3 ºC, Hum. 78 %, B...  8.286863e+08   ca
# 5342                       Got a bid for ΑΚΨ 🙌🙌🙌 #yessss  5.648980e+08  und
# 5510   RT @MyForwardMotion: @dannybrassell America's ...  7.004291e+08   ca
# 5544                                 iwant my mommie 😩😩😩  4.624466e+08   tl
# 6261                  Up :v RT @nurull_nrll: @radit_rdts  1.638134e+09  und
# 6676   RT @Meri_Sanny: and its #HappyBirthdaySanayaIr...  4.154739e+07   hi
# 7396   Nerve consultative services: ifgpG http://t.co...  1.223729e+09   ro
# 7832                                           Headache.  2.163157e+09   et
# 8574   Toshiba Satellite A505-S6005 16" 500 GB i3 1st...  1.661456e+09  und
# 9301             I LVOE YHSI SONG http://t.co/07VT5fQXUE  1.317287e+09   da
# 9505   Rudi rongai wewe RT @fab_louisa  Umo mtu hawez...  4.736298e+07   tl
# 9839      RT @bidmegoodbye: Aite! http://t.co/XfSLbarfPc  5.359198e+07   eu
# 10242                              @WhatsGoodTv ❤️🙌😎 OTF  3.091455e+08  und
# 10599                                 @mishacollins OMFH  2.944143e+08   ht
# 10886  [Аккорды] Evanescence - Forgive me http://t.co...  1.941419e+09  und
# 11019  7⃣1⃣1⃣🐥 @soypaulinagoto @soypinkteam #KCAMéxic...  6.278982e+08  und
# 11676  ► Gifts for the Holidays ◄  от Art Gallery на ...  2.463440e+09  und
# 11951                                             * it's  2.628276e+09  und
# 12210  RT @pourmecoffee: U-S-A! \nU-S-A!\nhttp://t.co...  2.361786e+07   in
# 12859                                          Lip ring            NaN  NaN
# 13161  "Wiggle" tradus in romana ! http://t.co/OwYaGL...  9.845120e+08   ro
# 13485                            @camerondallas no idea.  1.750714e+08   eu
# 13700  RT @PlumAlyssum: http://t.co/lK0a6f9yfw\n\n(do...  2.765688e+08   ht
# 14282  @Ashton5SOS  \n ABCDEFGHIJKLMNOPQRSTUVWXZY.  N...  2.767831e+09   cs
# 14374                  Hahaha that was hilarious #Comish  4.721989e+07   tl
# 14402  UK: Electoral fraud in #Scottish independence ...  3.360760e+08   ro
# 15096                                    PrayforAugust 💕  2.771906e+09  und
# 15105                                @DavidRayahin u 1st  7.646202e+07  und
# 15624                                     Begin Again ❤️  2.410635e+07   eu
#
#               sent
# 200        Neutral
# 823        Neutral
# 828        Neutral
# 879        Neutral
# 932    Non_neutral
# 1107       Neutral
# 1934       Neutral
# 2647       Neutral
# 3038       Neutral
# 3719       Neutral
# 3954       Neutral
# 4253       Neutral
# 5342   Non_neutral
# 5510       Neutral
# 5544   Non_neutral
# 6261       Neutral
# 6676   Non_neutral
# 7396       Neutral
# 7832   Non_neutral
# 8574       Neutral
# 9301   Non_neutral
# 9505       Neutral
# 9839       Neutral
# 10242  Non_neutral
# 10599      Neutral
# 10886      Neutral
# 11019      Neutral
# 11676      Neutral
# 11951      Neutral
# 12210  Non_neutral
# 12859      Neutral
# 13161      Neutral
# 13485      Neutral
# 13700      Neutral
# 14282      Neutral
# 14374  Non_neutral
# 14402      Neutral
# 15096      Neutral
# 15105      Neutral
# 15624  Non_neutral

# %%
## Check null values and n_unique
pd.concat([train_raw.isnull().sum(), train_raw.nunique()], axis=1).rename(columns = {0: 'is_null', 1: 'n_unique' })
# Out:
#        is_null  n_unique
# id           0     29543
# time         0     29023
# tweet        0     29543
# smth         3     29288
# lang         3        19
# sent         0         2

# %%
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English

nlp = English()
tokenizer = Tokenizer(nlp.vocab)

# train_raw= train_raw.drop(columns=['id','time','smth'])
train_raw['sent'] = train_raw['sent'].map(lambda label: True if label == 'Neutral' else False)
train_raw['len_tweet'] = train_raw['tweet'].map(lambda tweet: len(tweet))
train_raw['tokens'] = train_raw['tweet'].map(lambda tweet: [tok.text for tok in tokenizer(tweet)])
train_raw['n_tokens'] = train_raw['tokens'].map(lambda tokens: len(tokens))
train_raw['n_urls'] = train_raw['tokens'].map(lambda tokens: len( [tok for tok in tokens if 'http' in tok] ))


train_raw.head(5)
# Out:
#                    id                       time  \
# 0  511396190119022592  2014-09-15 06:08:47+00:00
# 1  511396219487133696  2014-09-15 06:08:54+00:00
# 2  511396894745309184  2014-09-15 06:11:35+00:00
# 3  511397226120097792  2014-09-15 06:12:54+00:00
# 4  511397255450853377  2014-09-15 06:13:01+00:00
#
#                                     tweet          smth lang   sent  \
# 0                   Puff puff pass ya hoe  4.551812e+08   en  False
# 1                 @jthizzle when was this  2.265380e+09   en   True
# 2   TGIM (Thank God Its Monday) baby! 😀😀😀  5.013839e+07   en  False
# 3  Peace Love Shea http://t.co/SVG2yzx8L0  4.733844e+08   en   True
# 4           Same. https://t.co/GmP7Kz35yK  2.279286e+08   en   True
#
#    len_tweet                                         tokens  n_tokens  n_urls
# 0         21                    [Puff, puff, pass, ya, hoe]         5       0
# 1         23                   [@jthizzle, when, was, this]         4       0
# 2         37  [TGIM, (Thank, God, Its, Monday), baby!, 😀😀😀]         7       0
# 3         38    [Peace, Love, Shea, http://t.co/SVG2yzx8L0]         4       1
# 4         29               [Same., https://t.co/GmP7Kz35yK]         2       1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.histplot(data=train_raw,x='n_tokens',kde=True, bins=20,hue='sent')
plt.subplot(1,3,2)
sns.histplot(data=train_raw,x='len_tweet',kde=True, bins=20,hue='sent')
plt.subplot(1,3,3)
sns.histplot(data=train_raw,x='n_urls',kde=True, bins=20,hue='sent')
plt.show()

# %%
# Heatmap for later use
plt.figure(figsize=(12, 8))
sns.set(font_scale=1.5)
sns.heatmap(train_raw.corr(), cmap='coolwarm', annot=True, annot_kws={'size':15})
plt.show()

# %%
# # This is for spell checking, might be useful

# from tqdm import tqdm
# import pkg_resources
# from symspellpy import SymSpell, Verbosity

# sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
# dictionary_path = pkg_resources.resource_filename(
#     "symspellpy", "frequency_dictionary_en_82_765.txt")
# bigram_path = pkg_resources.resource_filename(
#     "symspellpy", "frequency_bigramdictionary_en_243_342.txt")
# # term_index is the column of the term and count_index is the
# # column of the term frequency
# sym_spell.load_dictionary(dictionary_path, term_index=0, count_index=1)
# sym_spell.load_bigram_dictionary(bigram_path, term_index=0, count_index=2)

# def check_spell(input_term):
#     # lookup suggestions for multi-word input strings (supports compound
#     # splitting & merging)
#     # max edit distance per lookup (per single word, not per whole input string)
#     suggestions = sym_spell.lookup_compound(input_term, max_edit_distance=2)
#     # display suggestion term, edit distance, and term frequency
#     pbar.update()
#     return suggestions[0]._term

# pbar = tqdm(total=len(train['search_term']))
# train['search_term'] = train['search_term'].map(check_spell)
# pbar.close()
